# %% [markdown]
# <a href="https://colab.research.google.com/github/mrdbourke/pytorch-deep-learning/blob/main/extras/exercises/04_pytorch_custom_datasets_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 04. PyTorch Custom Datasets Exercises Template
#
# Welcome to the 04. PyTorch Custom Datasets exercise template.
#
# The best way to practice PyTorch code is to write more PyTorch code.
#
# So read the original notebook and try to complete the exercises by writing code where it's required.
#
# Feel free to reference the original resources whenever you need but should practice writing all of the code yourself.
#
# ## Resources
#
# 1. These exercises/solutions are based on [notebook 04 of the Learn PyTorch for Deep Learning course](https://www.learnpytorch.io/04_pytorch_custom_datasets/).
# 2. See a live [walkthrough of the solutions (errors and all) on YouTube](https://youtu.be/vsFMF9wqWx0).
# 3. See [other solutions on the course GitHub](https://github.com/mrdbourke/pytorch-deep-learning/tree/main/extras/solutions).

# %%
# Check for GPU
# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi

# %%
# Import torch
import torch
from torch import nn

# Exercises require PyTorch > 1.10.0
print(torch.__version__)

# Setup device agnostic code
device = "mps" if torch.backends.mps.is_available() else "cpu"
device
# Out:
# 2.2.2
# 'mps'

# %% [markdown]
# ## 1. Our models are underperforming (not fitting the data well). What are 3 methods for preventing underfitting? Write them down and explain each with a sentence.

# %% [markdown]
# 1. Get more data
# 2. Add more hidden layers and more neurons in each layer
# 3. Training for longer (increase the number of epochs)
# 4. Use **Transfer Learning**

# %% [markdown]
# ## 2. Recreate the data loading functions we built in [sections 1, 2, 3 and 4 of notebook 04](https://www.learnpytorch.io/04_pytorch_custom_datasets/). You should have train and test `DataLoader`'s ready to use.

# %%
# 1. Get data
import requests
from pathlib import Path
import zipfile

folder = Path('data_for_excercise')
image_path = folder/'pizza_steak_sushi'

if image_path.is_dir():
    print(f"{image_path} already exists")
else:
    image_path.mkdir(parents = True, exist_ok=True)

    request = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi.zip")
    with open(image_path/"pizza_steak_sushi.zip", 'wb') as f:
        print("Downloading the file")
        f.write(request.content)
        
    with zipfile.ZipFile(image_path/'pizza_steak_sushi.zip','r') as zip_ref:
        print("Extracting the file")
        zip_ref.extractall(image_path)
# Out:
# data_for_excercise/pizza_steak_sushi already exists

# %%
# 2. Become one with the data
import os
def walk_through_dir(dir_path):
  """Walks through dir_path returning file counts of its contents."""
  for dirpath, dirnames, filenames in os.walk(dir_path):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")

# %%
walk_through_dir(image_path)
# Out:
# There are 2 directories and 1 images in 'data_for_excercise/pizza_steak_sushi'.
# There are 3 directories and 0 images in 'data_for_excercise/pizza_steak_sushi/test'.
# There are 0 directories and 19 images in 'data_for_excercise/pizza_steak_sushi/test/steak'.
# There are 0 directories and 31 images in 'data_for_excercise/pizza_steak_sushi/test/sushi'.
# There are 0 directories and 25 images in 'data_for_excercise/pizza_steak_sushi/test/pizza'.
# There are 3 directories and 0 images in 'data_for_excercise/pizza_steak_sushi/train'.
# There are 0 directories and 75 images in 'data_for_excercise/pizza_steak_sushi/train/steak'.
# There are 0 directories and 72 images in 'data_for_excercise/pizza_steak_sushi/train/sushi'.
# There are 0 directories and 78 images in 'data_for_excercise/pizza_steak_sushi/train/pizza'.

# %%
# Setup train and testing paths
train_dir = image_path/'train'
test_dir = image_path/'test'

train_dir,test_dir
# Out:
# (PosixPath('data_for_excercise/pizza_steak_sushi/train'),
#  PosixPath('data_for_excercise/pizza_steak_sushi/test'))

# %%
# Visualize an image
import pathlib
from pathlib import Path
from PIL import Image
import random

img_path_list = list(pathlib.Path(image_path).glob('*/*/*.jpg'))
len(img_path_list),type(img_path_list),img_path_list[:10]

# choose a random sample
rand_img = random.choice(img_path_list)

# open an image
first_image = Image.open(img_path_list[0])
random_image = Image.open(rand_img)
first_image
random_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=341x512>

# %%
# Do the image visualization with matplotlib

import matplotlib.pyplot as plt
import numpy as np

random_image = random.choice(img_path_list)


image = Image.open(random_image)
image_class = random_image.parent.stem
img_as_numpy = np.asarray(image)

plt.figure(figsize = (10,8))
plt.imshow(img_as_numpy)
plt.title(image_class)
plt.axis(False)
# Out:
# (-0.5, 511.5, 511.5, -0.5)

# %%
type(img_path_list)
# Out:
# list

# %%
type(random_image)
# Out:
# pathlib.PosixPath

# %%
img_path_list[0].parent.stem
# Out:
# 'steak'

# %% [markdown]
# We've got some images in our folders.
#
# Now we need to make them compatible with PyTorch by:
# 1. Transform the data into tensors.
# 2. Turn the tensor data into a `torch.utils.data.Dataset` and later a `torch.utils.data.DataLoader`.

# %%
# 3.1 Transforming data with torchvision.transforms
from torchvision import transforms

img_train_transform = transforms.Compose([
    transforms.Resize(size = (64,64)),
    transforms.RandomHorizontalFlip(p = 0.5),
    transforms.ToTensor()
    
])

img_test_transform = transforms.Compose([
    transforms.Resize(size = (64,64)),
    transforms.ToTensor()
])

# %%
# Write transform for turning images into tensors
transform_img = img_train_transform(image)
print(f"Transformed Image Shape: {transform_img.shape}")
plt.imshow(transform_img.permute(1,2,0)) # CHW --> HWC : matplotlib takes the image as HWC
plt.title(pathlib.Path(random_image).parent.stem)
# Out:
# Transformed Image Shape: torch.Size([3, 64, 64])
# Text(0.5, 1.0, 'sushi')

# %%
# Write a function to plot transformed images
def plot_original_and_transformed_img(data: str,
                                     transform):
    img_list = list(pathlib.Path(data).glob('*/*/*.jpg'))
    random_imgs = list(random.sample(img_list,k = 6))

    

    for img in random_imgs:
        with Image.open(img) as f:
            
            # Convert the image into numpy
            img_numpy = np.asarray(f)

            fig,ax = plt.subplots(nrows= 1,ncols =2)
            # plot the image
            ax[0].imshow(img_numpy)
            ax[0].set_title(img.parent.stem)
            ax[0].axis(False)

            # Transformed the image
            transformed_img = transform(f)

            ax[1].imshow(transformed_img.permute(1,2,0))
            ax[1].set_title(img.parent.stem)
            ax[1].axis(False)

# %%
img_list = list(pathlib.Path(train_dir).glob('*/*.jpg'))

# %%
visualized_img = plot_original_and_transformed_img(data=image_path,
                                                  transform=img_train_transform)

# %% [markdown]
# ### Load image data using `ImageFolder`

# %%
# Use ImageFolder to create dataset(s)

from torchvision import datasets
train_data = datasets.ImageFolder(root = train_dir,
                                 transform = img_train_transform)

test_data = datasets.ImageFolder(root = test_dir,
                                transform = img_test_transform)

# %%
# Get class names as a list
class_names = train_data.classes
class_names
# Out:
# ['pizza', 'steak', 'sushi']

# %%
# Can also get class names as a dict
class_dict = train_data.class_to_idx
class_dict
# Out:
# {'pizza': 0, 'steak': 1, 'sushi': 2}

# %%
# Check the lengths of each dataset
len(train_data), len(test_data)
# Out:
# (225, 75)

# %%
# Turn train and test Datasets into DataLoaders
from torch.utils.data import DataLoader
random.seed(42)
torch.manual_seed(42)
torch.mps.manual_seed(42)

BATCH_SIZE = 1

train_dataloader = DataLoader(dataset=train_data,
                             batch_size=BATCH_SIZE,
                             shuffle = True)

test_dataloader = DataLoader(dataset= test_data,
                            batch_size = BATCH_SIZE,
                            shuffle = False)

# %%
per_batch_img,per_batch_label = next(iter(train_dataloader))
per_batch_img.shape,per_batch_label.shape
# Out:
# (torch.Size([1, 3, 64, 64]), torch.Size([1]))

# %%
# How many batches of images are in our data loaders?
len(train_dataloader),len(test_dataloader)
# Out:
# (225, 75)

# %% [markdown]
# ## 3. Recreate `model_0` we built in section 7 of notebook 04.

# %%
import torch.nn as nn

class TinyVGGModelV0(nn.Module):
    def __init__(self,
                 input_shape:int,
                 hidden_units:int,
                 output_shape:int
                ):
        super().__init__()


        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                     out_channels=hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                     out_channels=hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=hidden_units,
                     out_channels=hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                     out_channels=hidden_units,
                     kernel_size=3,
                     stride=1,
                     padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features = hidden_units*16*16,
                     out_features = output_shape)
        )
    
    def forward(self,x):

        return self.classifier(self.conv2(self.conv1(x)))

# %% [markdown]
# ## 4. Create training and testing functions for `model_0`.

# %%
model_0 = TinyVGGModelV0(input_shape=3,
                        hidden_units=10,
                        output_shape=len(class_names)).to(device)

# %%
import torchinfo
from torchinfo import summary

summary(model_0,input_size = [1,3,64,64])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TinyVGGModelV0                           [1, 3]                    --
# ├─Sequential: 1-1                        [1, 10, 32, 32]           --
# │    └─Conv2d: 2-1                       [1, 10, 64, 64]           280
# │    └─ReLU: 2-2                         [1, 10, 64, 64]           --
# │    └─Conv2d: 2-3                       [1, 10, 64, 64]           910
# │    └─ReLU: 2-4                         [1, 10, 64, 64]           --
# │    └─MaxPool2d: 2-5                    [1, 10, 32, 32]           --
# ├─Sequential: 1-2                        [1, 10, 16, 16]           --
# │    └─Conv2d: 2-6                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-7                         [1, 10, 32, 32]           --
# │    └─Conv2d: 2-8                       [1, 10, 32, 32]           910
# │    └─ReLU: 2-9                         [1, 10, 32, 32]           --
# │    └─MaxPool2d: 2-10                   [1, 10, 16, 16]           --
# ├─Sequential: 1-3                        [1, 3]                    --
# │    └─Flatten: 2-11                     [1, 2560]                 --
# │    └─Linear: 2-12                      [1, 3]                    7,683
# ==========================================================================================
# Total params: 10,693
# Trainable params: 10,693
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 6.75
# ==========================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.82
# Params size (MB): 0.04
# Estimated Total Size (MB): 0.91
# ==========================================================================================

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
    
    
    # Put the model in train mode
    model.train()
    
    # Setup train loss and train accuracy values
    train_loss, train_acc = 0, 0
    
    # Loop through data loader and data batches
    for batch, (X,y) in enumerate(dataloader):
         
    # Send data to target device
        X , y = X.to(device),y.to(device)
    # 1. Forward pass
        y_logit = model(X)
    # 2. Calculate and accumulate loss
        loss = loss_fn(y_logit,y)
        train_loss +=loss.item()
    
    # 3. Optimizer zero grad 
        optimizer.zero_grad()
    
    # 4. Loss backward 
        loss.backward()
    
    # 5. Optimizer step
        optimizer.step()
    
    # Calculate and accumualte accuracy metric across all batches
        y_pred_class = torch.argmax(y_logit,dim =1)
        acc = (y_pred_class ==y).sum().item()
        train_acc +=acc

    # Adjust metrics to get average loss and average accuracy per batch
    train_loss = train_loss/len(dataloader)
    train_acc = train_acc/len(dataloader)

    
    return train_loss,train_acc

# %%
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):
  
    # Put model in eval mode
    model.eval()
    
    # Setup the test loss and test accuracy values
    test_loss, test_acc = 0, 0
    
    # Turn on inference context manager
    with torch.inference_mode():
    # Loop through DataLoader batches
        for batch,(X,y) in enumerate(dataloader):
            
            # Send data to target device
            X,y = X.to(device),y.to(device)
            
            # 1. Forward pass
            y_logit = model(X)
            y_pred_label = torch.argmax(y_logit,dim = 1)  
            
            # 2. Calculuate and accumulate loss
            loss = loss_fn(y_logit,y)
            test_loss +=loss
            
            # Calculate and accumulate accuracy
            acc = (y_pred_label==y).sum().item()
            test_acc +=acc
            
            # Adjust metrics to get average loss and accuracy per batch
        test_loss = test_loss/len(dataloader)
        test_acc = test_acc/len(dataloader)

    return test_loss,test_acc

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int = 5):
  
  # Create results dictionary
  results = {"train_loss": [],
             "train_acc": [],
             "test_loss": [],
             "test_acc": []}

  # Loop through the training and testing steps for a number of epochs
  for epoch in tqdm(range(epochs)):
    # Train step
    train_loss, train_acc = train_step(model=model, 
                                       dataloader=train_dataloader,
                                       loss_fn=loss_fn,
                                       optimizer=optimizer)
    # Test step
    test_loss, test_acc = test_step(model=model, 
                                    dataloader=test_dataloader,
                                    loss_fn=loss_fn)
    
    # Print out what's happening
    print(f"Epoch: {epoch+1} | "
          f"train_loss: {train_loss:.4f} | "
          f"train_acc: {train_acc:.4f} | "
          f"test_loss: {test_loss:.4f} | "
          f"test_acc: {test_acc:.4f}"
    )

    # Update the results dictionary
    results["train_loss"].append(train_loss)
    results["train_acc"].append(train_acc)
    results["test_loss"].append(test_loss)
    results["test_acc"].append(test_acc)

  # Return the results dictionary
  return results

# %% [markdown]
# ## 5. Try training the model you made in exercise 3 for 5, 20 and 50 epochs, what happens to the results?
# * Use `torch.optim.Adam()` with a learning rate of 0.001 as the optimizer.

# %%
# Train for 5 epochs
torch.manual_seed(42)
torch.mps.manual_seed(42)

model_0 = TinyVGGModelV0(input_shape=3,
                        hidden_units=10,
                        output_shape=len(class_names)).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_0.parameters(), 
                             lr=0.001)

five_epoch_train = train(model= model_0,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=5)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1172 | train_acc: 0.2978 | test_loss: 1.0970 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.1008 | train_acc: 0.3289 | test_loss: 1.0993 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.0994 | train_acc: 0.3067 | test_loss: 1.0986 | test_acc: 0.3200
# Epoch: 4 | train_loss: 1.0948 | train_acc: 0.4000 | test_loss: 1.0848 | test_acc: 0.4800
# Epoch: 5 | train_loss: 0.9835 | train_acc: 0.5467 | test_loss: 0.9944 | test_acc: 0.4667

# %%
# Train for 20 epochs
torch.manual_seed(42)
torch.mps.manual_seed(42)

model_1 = TinyVGGModelV0(input_shape=3,
                        hidden_units=10,
                        output_shape=len(class_names)).to(device)


loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_1.parameters(), 
                             lr=0.001)
twenty_epoch_train = train(model= model_1,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1172 | train_acc: 0.2978 | test_loss: 1.0970 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.1008 | train_acc: 0.3289 | test_loss: 1.0993 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.0994 | train_acc: 0.3067 | test_loss: 1.0986 | test_acc: 0.3200
# Epoch: 4 | train_loss: 1.0948 | train_acc: 0.4000 | test_loss: 1.0848 | test_acc: 0.4800
# Epoch: 5 | train_loss: 0.9835 | train_acc: 0.5467 | test_loss: 0.9944 | test_acc: 0.4667
# Epoch: 6 | train_loss: 0.9359 | train_acc: 0.6044 | test_loss: 1.0609 | test_acc: 0.4533
# Epoch: 7 | train_loss: 0.8692 | train_acc: 0.6178 | test_loss: 1.1580 | test_acc: 0.4533
# Epoch: 8 | train_loss: 0.8351 | train_acc: 0.6222 | test_loss: 0.9875 | test_acc: 0.4267
# Epoch: 9 | train_loss: 0.8018 | train_acc: 0.6267 | test_loss: 1.0213 | test_acc: 0.4400
# Epoch: 10 | train_loss: 0.7669 | train_acc: 0.6267 | test_loss: 1.1329 | test_acc: 0.4267
# Epoch: 11 | train_loss: 0.7329 | train_acc: 0.6400 | test_loss: 1.0743 | test_acc: 0.4533
# Epoch: 12 | train_loss: 0.6932 | train_acc: 0.6933 | test_loss: 1.2494 | test_acc: 0.4800
# Epoch: 13 | train_loss: 0.6605 | train_acc: 0.6889 | test_loss: 1.3450 | test_acc: 0.4133
# Epoch: 14 | train_loss: 0.6527 | train_acc: 0.7244 | test_loss: 1.2492 | test_acc: 0.4133
# Epoch: 15 | train_loss: 0.6162 | train_acc: 0.7200 | test_loss: 1.2685 | test_acc: 0.4533
# Epoch: 16 | train_loss: 0.6565 | train_acc: 0.7378 | test_loss: 1.1595 | test_acc: 0.4533
# Epoch: 17 | train_loss: 0.6213 | train_acc: 0.7378 | test_loss: 1.2068 | test_acc: 0.5067
# Epoch: 18 | train_loss: 0.5651 | train_acc: 0.7556 | test_loss: 1.2139 | test_acc: 0.5467
# Epoch: 19 | train_loss: 0.5529 | train_acc: 0.8044 | test_loss: 1.2622 | test_acc: 0.5200
# Epoch: 20 | train_loss: 0.4974 | train_acc: 0.7867 | test_loss: 1.5625 | test_acc: 0.5333

# %%
for param in model_0.parameters():
    print(param.requires_grad)  # Should be True
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
# Train for 50 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_2 = TinyVGGModelV0(input_shape=3,
                        hidden_units=10,
                        output_shape=len(class_names)).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_2.parameters(), 
                             lr=0.001)
ifty_epoch_train = train(model= model_2,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=50)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1172 | train_acc: 0.2978 | test_loss: 1.0970 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.1008 | train_acc: 0.3289 | test_loss: 1.0993 | test_acc: 0.3333
# Epoch: 3 | train_loss: 1.0994 | train_acc: 0.3067 | test_loss: 1.0986 | test_acc: 0.3200
# Epoch: 4 | train_loss: 1.0948 | train_acc: 0.4000 | test_loss: 1.0848 | test_acc: 0.4800
# Epoch: 5 | train_loss: 0.9835 | train_acc: 0.5467 | test_loss: 0.9944 | test_acc: 0.4667
# Epoch: 6 | train_loss: 0.9359 | train_acc: 0.6044 | test_loss: 1.0609 | test_acc: 0.4533
# Epoch: 7 | train_loss: 0.8692 | train_acc: 0.6178 | test_loss: 1.1580 | test_acc: 0.4533
# Epoch: 8 | train_loss: 0.8351 | train_acc: 0.6222 | test_loss: 0.9875 | test_acc: 0.4267
# Epoch: 9 | train_loss: 0.8018 | train_acc: 0.6267 | test_loss: 1.0213 | test_acc: 0.4400
# Epoch: 10 | train_loss: 0.7669 | train_acc: 0.6267 | test_loss: 1.1329 | test_acc: 0.4267
# Epoch: 11 | train_loss: 0.7329 | train_acc: 0.6400 | test_loss: 1.0743 | test_acc: 0.4533
# Epoch: 12 | train_loss: 0.6932 | train_acc: 0.6933 | test_loss: 1.2494 | test_acc: 0.4800
# Epoch: 13 | train_loss: 0.6605 | train_acc: 0.6889 | test_loss: 1.3450 | test_acc: 0.4133
# Epoch: 14 | train_loss: 0.6527 | train_acc: 0.7244 | test_loss: 1.2492 | test_acc: 0.4133
# Epoch: 15 | train_loss: 0.6162 | train_acc: 0.7200 | test_loss: 1.2685 | test_acc: 0.4533
# Epoch: 16 | train_loss: 0.6565 | train_acc: 0.7378 | test_loss: 1.1595 | test_acc: 0.4533
# Epoch: 17 | train_loss: 0.6213 | train_acc: 0.7378 | test_loss: 1.2068 | test_acc: 0.5067
# Epoch: 18 | train_loss: 0.5651 | train_acc: 0.7556 | test_loss: 1.2139 | test_acc: 0.5467
# Epoch: 19 | train_loss: 0.5529 | train_acc: 0.8044 | test_loss: 1.2622 | test_acc: 0.5200
# Epoch: 20 | train_loss: 0.4974 | train_acc: 0.7867 | test_loss: 1.5625 | test_acc: 0.5333
# Epoch: 21 | train_loss: 0.4793 | train_acc: 0.8267 | test_loss: 1.4919 | test_acc: 0.4933
# Epoch: 22 | train_loss: 0.4027 | train_acc: 0.8356 | test_loss: 1.5452 | test_acc: 0.5067
# Epoch: 23 | train_loss: 0.3851 | train_acc: 0.8311 | test_loss: 1.7841 | test_acc: 0.4933
# Epoch: 24 | train_loss: 0.3296 | train_acc: 0.8667 | test_loss: 1.8937 | test_acc: 0.4800
# Epoch: 25 | train_loss: 0.2906 | train_acc: 0.8844 | test_loss: 2.2381 | test_acc: 0.4533
# Epoch: 26 | train_loss: 0.2632 | train_acc: 0.9067 | test_loss: 2.3972 | test_acc: 0.4400
# Epoch: 27 | train_loss: 0.2290 | train_acc: 0.9067 | test_loss: 2.2084 | test_acc: 0.4800
# Epoch: 28 | train_loss: 0.2593 | train_acc: 0.9111 | test_loss: 2.1322 | test_acc: 0.4667
# Epoch: 29 | train_loss: 0.2036 | train_acc: 0.9244 | test_loss: 2.3084 | test_acc: 0.4933
# Epoch: 30 | train_loss: 0.1438 | train_acc: 0.9600 | test_loss: 2.4545 | test_acc: 0.5200
# Epoch: 31 | train_loss: 0.1199 | train_acc: 0.9511 | test_loss: 2.7349 | test_acc: 0.4667
# Epoch: 32 | train_loss: 0.1195 | train_acc: 0.9644 | test_loss: 2.9166 | test_acc: 0.4667
# Epoch: 33 | train_loss: 0.0663 | train_acc: 0.9822 | test_loss: 3.1809 | test_acc: 0.4933
# Epoch: 34 | train_loss: 0.1074 | train_acc: 0.9556 | test_loss: 3.4148 | test_acc: 0.5200
# Epoch: 35 | train_loss: 0.0861 | train_acc: 0.9600 | test_loss: 3.5493 | test_acc: 0.5333
# Epoch: 36 | train_loss: 0.1321 | train_acc: 0.9600 | test_loss: 4.2642 | test_acc: 0.4533
# Epoch: 37 | train_loss: 0.0931 | train_acc: 0.9644 | test_loss: 3.4818 | test_acc: 0.4667
# Epoch: 38 | train_loss: 0.0706 | train_acc: 0.9822 | test_loss: 3.9732 | test_acc: 0.4933
# Epoch: 39 | train_loss: 0.0429 | train_acc: 0.9911 | test_loss: 3.9246 | test_acc: 0.4800
# Epoch: 40 | train_loss: 0.0314 | train_acc: 0.9911 | test_loss: 4.2503 | test_acc: 0.4533
# Epoch: 41 | train_loss: 0.1539 | train_acc: 0.9378 | test_loss: 4.1720 | test_acc: 0.4267
# Epoch: 42 | train_loss: 0.0843 | train_acc: 0.9733 | test_loss: 3.6439 | test_acc: 0.4667
# Epoch: 43 | train_loss: 0.0867 | train_acc: 0.9644 | test_loss: 3.7821 | test_acc: 0.4933
# Epoch: 44 | train_loss: 0.0225 | train_acc: 0.9956 | test_loss: 3.9696 | test_acc: 0.4667
# Epoch: 45 | train_loss: 0.0229 | train_acc: 0.9956 | test_loss: 4.1973 | test_acc: 0.4667
# Epoch: 46 | train_loss: 0.0116 | train_acc: 0.9956 | test_loss: 4.3187 | test_acc: 0.4667
# Epoch: 47 | train_loss: 0.0086 | train_acc: 1.0000 | test_loss: 4.5423 | test_acc: 0.4400
# Epoch: 48 | train_loss: 0.0086 | train_acc: 1.0000 | test_loss: 4.9601 | test_acc: 0.4667
# Epoch: 49 | train_loss: 0.0068 | train_acc: 1.0000 | test_loss: 4.9901 | test_acc: 0.4533
# Epoch: 50 | train_loss: 0.0104 | train_acc: 0.9956 | test_loss: 5.1286 | test_acc: 0.4533

# %% [markdown]
# It looks like our model is starting to overfit towards the end (performing far better on the training data than on the testing data).
#
# In order to fix this, we'd have to introduce ways of preventing overfitting.

# %% [markdown]
# ## 6. Double the number of hidden units in your model and train it for 20 epochs, what happens to the results?

# %%
# Double the number of hidden units and train for 20 epochs
torch.manual_seed(42)
torch.cuda.manual_seed(42)
model_3 = TinyVGGModelV0(input_shape = 3,
                        hidden_units = 20,
                        output_shape = len(class_names)).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_3.parameters(),
                            lr = 0.001)
twenty_epoch_model_1_train = train(model= model_3,
                        train_dataloader=train_dataloader,
                        test_dataloader=test_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=20)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.0977 | train_acc: 0.3511 | test_loss: 1.0888 | test_acc: 0.3333
# Epoch: 2 | train_loss: 1.0992 | train_acc: 0.3378 | test_loss: 1.0803 | test_acc: 0.3600
# Epoch: 3 | train_loss: 1.1008 | train_acc: 0.3822 | test_loss: 1.1013 | test_acc: 0.2400
# Epoch: 4 | train_loss: 1.1012 | train_acc: 0.4133 | test_loss: 1.0995 | test_acc: 0.2533
# Epoch: 5 | train_loss: 1.0958 | train_acc: 0.3644 | test_loss: 1.0791 | test_acc: 0.3600
# Epoch: 6 | train_loss: 1.0963 | train_acc: 0.3600 | test_loss: 1.1027 | test_acc: 0.2533
# Epoch: 7 | train_loss: 1.0667 | train_acc: 0.4400 | test_loss: 1.0163 | test_acc: 0.4667
# Epoch: 8 | train_loss: 1.0927 | train_acc: 0.4756 | test_loss: 0.9868 | test_acc: 0.4533
# Epoch: 9 | train_loss: 0.9426 | train_acc: 0.5378 | test_loss: 1.0667 | test_acc: 0.4400
# Epoch: 10 | train_loss: 0.8929 | train_acc: 0.6000 | test_loss: 1.0323 | test_acc: 0.4933
# Epoch: 11 | train_loss: 0.8348 | train_acc: 0.6489 | test_loss: 1.0262 | test_acc: 0.4400
# Epoch: 12 | train_loss: 0.8166 | train_acc: 0.6178 | test_loss: 1.0289 | test_acc: 0.4667
# Epoch: 13 | train_loss: 0.7672 | train_acc: 0.6622 | test_loss: 1.2245 | test_acc: 0.4933
# Epoch: 14 | train_loss: 0.7348 | train_acc: 0.6889 | test_loss: 1.0952 | test_acc: 0.4800
# Epoch: 15 | train_loss: 0.6693 | train_acc: 0.7022 | test_loss: 1.1358 | test_acc: 0.4267
# Epoch: 16 | train_loss: 0.6738 | train_acc: 0.7111 | test_loss: 1.1603 | test_acc: 0.4400
# Epoch: 17 | train_loss: 0.6313 | train_acc: 0.7156 | test_loss: 1.2351 | test_acc: 0.4267
# Epoch: 18 | train_loss: 0.5551 | train_acc: 0.7556 | test_loss: 1.4301 | test_acc: 0.4000
# Epoch: 19 | train_loss: 0.5523 | train_acc: 0.7644 | test_loss: 1.2906 | test_acc: 0.4000
# Epoch: 20 | train_loss: 0.4871 | train_acc: 0.8000 | test_loss: 1.4049 | test_acc: 0.4533

# %% [markdown]
# It looks like the model is still overfitting, even when changing the number of hidden units.
#
# To fix this, we'd have to look at ways to prevent overfitting with our model.

# %% [markdown]
# ## 7. Double the data you're using with your model from step 6 and train it for 20 epochs, what happens to the results?
# * **Note:** You can use the [custom data creation notebook](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/extras/04_custom_data_creation.ipynb) to scale up your Food101 dataset.
# * You can also find the [already formatted double data (20% instead of 10% subset) dataset on GitHub](https://github.com/mrdbourke/pytorch-deep-learning/blob/main/data/pizza_steak_sushi_20_percent.zip), you will need to write download code like in exercise 2 to get it into this notebook.

# %%
# Download 20% data for Pizza/Steak/Sushi from GitHub
import requests
import zipfile
from pathlib import Path

# Setup path to data folder
data_path = Path("data/")
image_path = data_path / "pizza_steak_sushi_20_percent"

# If the image folder doesn't exist, download it and prepare it... 
if image_path.is_dir():
    print(f"{image_path} directory exists.")
else:
    print(f"Did not find {image_path} directory, creating one...")
    image_path.mkdir(parents=True, exist_ok=True)
    
# Download pizza, steak, sushi data
with open(data_path / "pizza_steak_sushi_20_percent.zip", "wb") as f:
    request = requests.get("https://github.com/mrdbourke/pytorch-deep-learning/raw/main/data/pizza_steak_sushi_20_percent.zip")
    print("Downloading pizza, steak, sushi 20% data...")
    f.write(request.content)

# Unzip pizza, steak, sushi data
with zipfile.ZipFile(data_path / "pizza_steak_sushi_20_percent.zip", "r") as zip_ref:
    print("Unzipping pizza, steak, sushi 20% data...") 
    zip_ref.extractall(image_path)
# Out:
# Did not find data/pizza_steak_sushi_20_percent directory, creating one...
# Downloading pizza, steak, sushi 20% data...
# Unzipping pizza, steak, sushi 20% data...

# %%
# See how many images we have
walk_through_dir(image_path)
# Out:
# There are 2 directories and 0 images in 'data/pizza_steak_sushi_20_percent'.
# There are 3 directories and 0 images in 'data/pizza_steak_sushi_20_percent/test'.
# There are 0 directories and 58 images in 'data/pizza_steak_sushi_20_percent/test/steak'.
# There are 0 directories and 46 images in 'data/pizza_steak_sushi_20_percent/test/sushi'.
# There are 0 directories and 46 images in 'data/pizza_steak_sushi_20_percent/test/pizza'.
# There are 3 directories and 0 images in 'data/pizza_steak_sushi_20_percent/train'.
# There are 0 directories and 146 images in 'data/pizza_steak_sushi_20_percent/train/steak'.
# There are 0 directories and 150 images in 'data/pizza_steak_sushi_20_percent/train/sushi'.
# There are 0 directories and 154 images in 'data/pizza_steak_sushi_20_percent/train/pizza'.

# %% [markdown]
# Excellent, we now have double the training and testing images...

# %%
# Create the train and test paths
train_data_20_percent_path = image_path / "train"
test_data_20_percent_path = image_path / "test"

train_data_20_percent_path, test_data_20_percent_path
# Out:
# (PosixPath('data/pizza_steak_sushi_20_percent/train'),
#  PosixPath('data/pizza_steak_sushi_20_percent/test'))

# %%
# Turn the 20 percent datapaths into Datasets and DataLoaders
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader

simple_transform = transforms.Compose([
  transforms.Resize((64, 64)),                                     
  transforms.ToTensor()
])

# Create datasets
train_20_percent_data = datasets.ImageFolder(root = train_data_20_percent_path,
                                            transform=simple_transform)
test_20_percent_data = datasets.ImageFolder(root = test_data_20_percent_path,
                                            transform=simple_transform)
# Create dataloaders
train_20_percent_dataloader = DataLoader(dataset=train_20_percent_data,
                                        batch_size=1,
                                        shuffle = True)
test_20_percent_dataloader = DataLoader(dataset=test_20_percent_data,
                                        batch_size=1,
                                        shuffle = False)

# %%
len(train_20_percent_dataloader),len(test_20_percent_dataloader)
# Out:
# (450, 150)

# %%
class_names = train_20_percent_data.classes

# %%
class_names
# Out:
# ['pizza', 'steak', 'sushi']

# %%
# visualize some data:
plot_original_and_transformed_img(image_path,
                                 transform = simple_transform)

# %%
# Train a model with increased amount of data
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model_4 = TinyVGGModelV0(input_shape=3,
                        hidden_units=20,
                         output_shape=len(class_names)
                        ).to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_4.parameters(),
                            lr = 0.001)
twenty_epoch_model_4_train = train(model= model_4,
                        train_dataloader=train_20_percent_dataloader,
                        test_dataloader=test_20_percent_dataloader,
                        optimizer=optimizer,
                        loss_fn=loss_fn,
                        epochs=5)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 1.1042 | train_acc: 0.3133 | test_loss: 1.0989 | test_acc: 0.3067
# Epoch: 2 | train_loss: 1.0987 | train_acc: 0.3222 | test_loss: 1.0991 | test_acc: 0.3000
# Epoch: 3 | train_loss: 1.0950 | train_acc: 0.4089 | test_loss: 1.0849 | test_acc: 0.4533
# Epoch: 4 | train_loss: 1.0183 | train_acc: 0.5378 | test_loss: 0.9083 | test_acc: 0.6333
# Epoch: 5 | train_loss: 0.9269 | train_acc: 0.6000 | test_loss: 0.8939 | test_acc: 0.5533

# %% [markdown]
# ## 8. Make a prediction on your own custom image of pizza/steak/sushi (you could even download one from the internet) with your trained model from exercise 7 and share your prediction.
# * Does the model you trained in exercise 7 get it right?
# * If not, what do you think you could do to improve it?

# %%
# prepare the unknown image
image = Path('/Users/tinonturjamajumder/Pytorch/data/pizza_steak_sushi/steak.jpeg')

# %%
Image.open(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>

# %%
img = torchvision.io.read_image().type(torch.float32)

model_4.evel()

with torch.inference_mode():
    predict = model_4()

# %%
import torchvision
img = torchvision.io.read_image('/Users/tinonturjamajumder/Pytorch/data/pizza_steak_sushi/steak.jpeg').type(torch.float32)/255

# %%
img.shape
# Out:
# torch.Size([3, 194, 259])

# %%
steak_img ='/Users/tinonturjamajumder/Pytorch/data/pizza_steak_sushi/steak.jpeg'

# %%
import numpy as np
def predict_and_plot_unknown_img(model:torch.nn.Module,
                                img_path:str,
                                class_names,
                                transforms,
                                device):
    img = Image.open(Path(img_path))


    # Transform the image
    transformed_img = transforms(img)

    print(transformed_img.shape)

    # add batch size
    img_with_batch = transformed_img.unsqueeze(0).to(device)

    model.to(device)

    model.eval()

    with torch.inference_mode():
        predict = model(img_with_batch).argmax(dim =1).item()
        class_label = class_names[predict]

    plt.imshow(transformed_img.permute(1,2,0))
    plt.title(class_label)
    plt.axis(False)

# %%
device
# Out:
# 'mps'

# %%
guess = predict_and_plot_unknown_img(model_4,
                                    steak_img,
                                    class_names,
                                    simple_transform,
                                    device)
# Out:
# torch.Size([3, 64, 64])

# %%
npimg = np.array(img)
npimg.shape
# Out:
# (3, 194, 259)

# %%
sushi_img = '/Users/tinonturjamajumder/Pytorch/data/pizza_steak_sushi/download.jpeg'

guess = predict_and_plot_unknown_img(model_4,
                                    sushi_img,
                                    class_names,
                                    simple_transform,
                                    device)
# Out:
# torch.Size([3, 64, 64])

# %%
sushi_img_2 ='/Users/tinonturjamajumder/Pytorch/data/pizza_steak_sushi/sushi_img.jpeg'

guess = predict_and_plot_unknown_img(model_4,
                                    sushi_img_2,
                                    class_names,
                                    simple_transform,
                                    device)
# Out:
# torch.Size([3, 64, 64])

# %%
sushi_img_2 ='/Users/tinonturjamajumder/Pytorch/data/pizza_steak_sushi/sushi_img.jpeg'

guess = predict_and_plot_unknown_img(model_4,
                                    sushi_img_2,
                                    class_names,
                                    simple_transform,
                                    device)
